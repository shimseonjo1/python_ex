# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = np.random.randint(-100,100,50).cumsum()
data
# Out:
# array([ -40, -126,  -29,  -48,  -30,  -72,  -42,   54,  -44, -123, -206,
#        -228, -283, -335, -313, -220, -292, -328, -428, -380, -387, -385,
#        -309, -342, -356, -288, -268, -293, -384, -322, -299, -254, -257,
#        -345, -298, -202, -249, -231, -175, -235, -177, -229, -283, -360,
#        -399, -336, -404, -394, -470, -384], dtype=int32)

# %%
plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
# 1. 폰트 파일로 FontProperties()생성 후 사용

import matplotlib.font_manager as fm

path = '나눔손글씨 가람연꽃.ttf'
fontprop = fm.FontProperties(fname=path,size=15)

plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이',fontproperties=fontprop)
plt.ylabel('주식 가격',fontproperties=fontprop)
plt.xlabel('시간(분)',fontproperties=fontprop)
# Out:
# Text(0.5, 0, '시간(분)')

# %%
# 2. matplotlib.rcParams[]로 설정
import matplotlib

print('설정 파일 위치 : ', matplotlib.matplotlib_fname())
print('기본 설정 폰트 : ', plt.rcParams['font.family'])
print('기본 설정 사이즈 : ', plt.rcParams['font.size'])
# Out:
# 설정 파일 위치 :  C:\Users\admin\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 기본 설정 폰트 :  ['sans-serif']
# 기본 설정 사이즈 :  10.0

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 13
plt.rcParams['axes.unicode_minus'] = False

plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
fm.findSystemFonts()[:4]
# Out:
# ['C:\\Windows\\Fonts\\GIL_____.TTF',
#  'C:\\windows\\Fonts\\TEMPSITC.TTF',
#  'C:\\Windows\\Fonts\\GOUDYSTO.TTF',
#  'C:\\Windows\\Fonts\\H2GTRM.TTF']

# %%
[(f.name,f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('NanumSquare Neo Regular',
#   'C:\\Users\\admin\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareNeo-bRg.ttf'),
#  ('NanumSquare Neo Light',
#   'C:\\Users\\admin\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareNeo-aLt.ttf'),
#  ('NanumSquare Neo ExtraBold',
#   'C:\\Users\\admin\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareNeo-dEb.ttf'),
#  ('Nanum GaRamYeonGgoc',
#   'C:\\Users\\admin\\AppData\\Local\\Microsoft\\Windows\\Fonts\\나눔손글씨 가람연꽃.ttf'),
#  ('NanumSquare Neo Bold',
#   'C:\\Users\\admin\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareNeo-cBd.ttf'),
#  ('NanumSquare Neo Heavy',
#   'C:\\Users\\admin\\AppData\\Local\\Microsoft\\Windows\\Fonts\\NanumSquareNeo-eHv.ttf')]

# %%
plt.rcParams['font.family'] = 'NanumSquare Neo Light'
plt.rcParams['font.size'] = 13
plt.rcParams['axes.unicode_minus'] = False

plt.plot(range(50),data,'r')
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
# 3. 설정파일 수정
import matplotlib
import matplotlib.pyplot as plt

print('설정 파일 위치 : ', matplotlib.matplotlib_fname())
print('기본 설정 폰트 : ', plt.rcParams['font.family'])
print('기본 설정 사이즈 : ', plt.rcParams['font.size'])
# Out:
# 설정 파일 위치 :  C:\Users\admin\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# 기본 설정 폰트 :  ['Malgun Gothic']
# 기본 설정 사이즈 :  12.0
